# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv', on_bad_lines = 'skip')

# %%
data.head()
# Out:
#       password  strength
# 0     kzde5577         1
# 1     kino3434         1
# 2    visi7k1yr         1
# 3     megzy123         1
# 4  lamborghin1         1

# %%
data.columns
# Out:
# Index(['password', 'strength'], dtype='object')

# %% [markdown]
# # removing the Null Values

# %%
data = data.dropna()

# %%
data.head()
# Out:
#       password  strength
# 0     kzde5577         1
# 1     kino3434         1
# 2    visi7k1yr         1
# 3     megzy123         1
# 4  lamborghin1         1

# %% [markdown]
# # assigning the strength of password

# %%
data['strength'] = data['strength'].map({0: "weak",
                                        1: "Medium",
                                        2: "Hard"})
data.head()
# Out:
#       password strength
# 0     kzde5577   Medium
# 1     kino3434   Medium
# 2    visi7k1yr   Medium
# 3     megzy123   Medium
# 4  lamborghin1   Medium

# %%
data.sample(5)
# Out:
#                 password strength
# 549811          123465ab   Medium
# 584352  kX4DpvzM0Nw1DMF5     Hard
# 655820         punkesh21   Medium
# 496744         nagyfe614   Medium
# 543496            g0llum     weak

# %% [markdown]
# # Using tokenization

# %%
def word(password):
  character = []
  for i in password:
    character.append(i)
  return character

# %% [markdown]
# # assigning the values of X and y

# %%
X = np.array(data['password'])
y = np.array(data['strength'])

# %% [markdown]
# # Implementing the Tfidfvectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tdif = TfidfVectorizer(tokenizer=word)

# %%
X = tdif.fit_transform(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %% [markdown]
# # Feature scaling

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42)

# %% [markdown]
# # implementing randomforestvectorizer as a model

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_test, y_test)
# Out:
# 0.9572904844394002

# %% [markdown]
# # giving the user input

# %%
import getpass
user = getpass.getpass('Enter Password: ')
data = tdif.transform([user]).toarray()
output = model.predict(data)
print(output)
# Out:
# Enter Password: ··········
# ['Medium']
